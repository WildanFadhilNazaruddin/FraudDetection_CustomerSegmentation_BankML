# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/WIII.csv')
# Out:
# /tmp/ipykernel_18587/916828569.py:1: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/WIII.csv')

# %%
# menampilkan semua kolom
pd.set_option('display.max_columns', None)
# melihat sample data
df.head(5)
# Out:
#   station             valid       lon     lat  elevation   tmpf   dwpf   relh  \
# 0    WIII  2000-01-01 00:00  106.6589 -6.1255        8.0  78.00  76.00  94.21
# 1    WIII  2000-01-01 01:00  106.6589 -6.1255        8.0  80.60  78.80  94.27
# 2    WIII  2000-01-01 02:00  106.6589 -6.1255        8.0  82.40  78.80  88.90
# 3    WIII  2000-01-01 03:00  106.6589 -6.1255        8.0  80.60  77.72  90.97
# 4    WIII  2000-01-01 04:00  106.6589 -6.1255        8.0  82.40  78.80  88.90
#
#      drct  sknt p01i   alti     mslp  vsby gust skyc1 skyc2 skyc3 skyc4 skyl1  \
# 0  250.00  5.00    M  29.77  1008.40  4.00    M     M     M     M     M     M
# 1  300.00  4.00    M  29.77        M  6.00    M     M     M     M     M     M
# 2  340.00  6.00    M  29.77        M  7.00    M     M     M     M     M     M
# 3  350.00  4.00    M  29.77  1008.70  6.00    M     M     M     M     M     M
# 4  330.00  9.00    M  29.77        M  7.00    M     M     M     M     M     M
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374329 entries, 0 to 374328
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   station            374329 non-null  object
#  1   valid              374329 non-null  object
#  2   lon                374329 non-null  float64
#  3   lat                374329 non-null  float64
#  4   elevation          374329 non-null  float64
#  5   tmpf               374329 non-null  object
#  6   dwpf               374329 non-null  object
#  7   relh               374329 non-null  object
#  8   drct               374329 non-null  object
#  9   sknt               374329 non-null  object
#  10  p01i               374329 non-null  object
#  11  alti               374329 non-null  object
#  12  mslp               374329 non-null  object
#  13  vsby               374329 non-null  object
#  14  gust               374329 non-null  object
# ...
